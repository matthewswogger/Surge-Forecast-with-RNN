# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt
from tensorflow.contrib import learn
from sklearn.metrics import mean_squared_error
from lstm import lstm_model#, generate_data
from tensorflow.python.framework import dtypes
from tensorflow.contrib import learn

# %%
# MSE: 0.008449
LOG_DIR = './ops_logs/all_points_model'
TIMESTEPS = 5
RNN_LAYERS = [{'num_units': 40}, {'num_units': 20}]
DENSE_LAYERS = [10]
TRAINING_STEPS = 10000
PRINT_STEPS = TRAINING_STEPS / 10
BATCH_SIZE = 100

# %%
def prepare_and_split_data(df, TIMESTEPS):
    def build_dataframes_for_points(df):
        point_list = [0, 1, 2, 3, 14, 15, 16, 12, 13, 24, 25, 26, 27, 28, 17, 29]
        return [df[df.point == point].reset_index(drop=True)[:31184] for point in point_list]

    df_0,df_1,df_2,df_3,df_14,df_15,df_16,df_12,df_13,df_24,df_25,df_26,\
                                                            df_27,df_28,df_17,df_29 = build_dataframes_for_points(df)
        
    df_surge = pd.concat([df_0.surge, df_1.surge, df_2.surge, df_3.surge, df_14.surge, df_15.surge, df_16.surge,\
                      df_12.surge, df_13.surge, df_24.surge, df_25.surge, df_26.surge, df_27.surge, df_28.surge,\
                      df_17.surge, df_29.surge], axis=1, keys=['point_0', 'point_1', 'point_2', 'point_3', 'point_14',\
                        'point_15', 'point_16', 'point_12', 'point_13', 'point_24', 'point_25','point_26', 'point_27',\
                        'point_28', 'point_17', 'point_29'])
    
    df_forecast = df_surge[5:].reset_index(drop=True)# the number 5 is how far ahead we will predict
    df_surge = df_surge[:len(df_forecast)].reset_index(drop=True)
    my_y = np.array(df_forecast) # this is the target forecast of 5min ahead
    surge_np = np.array(df_surge)
    my_x = np.empty([len(my_y),TIMESTEPS,16]) # filled with zeros that will be replaced with surge data
    for i, points_row in enumerate(surge_np):
        time_chunk = surge_np[i:i+TIMESTEPS,:]
        if time_chunk.shape == (TIMESTEPS, 16):
            my_x[i,:,:] = time_chunk
        else:
            my_x[i,:,:] = np.ones((TIMESTEPS,16))
            
    # get values to split data into train,val,test split
    train_data_len_end = round(len(my_y)*.8)
    val_data_len_end = round(len(my_y)*.9)

    return dict(train=my_x[:train_data_len_end], val=my_x[train_data_len_end:val_data_len_end],\
                test=my_x[val_data_len_end:]), dict(train=my_y[:train_data_len_end],\
                val=my_y[train_data_len_end:val_data_len_end], test=my_y[val_data_len_end:])

# %%
X, y = prepare_and_split_data(pd.read_csv('mydata.csv'), TIMESTEPS)
# Out:
# /Users/matthewswogger/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:26: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
regressor = learn.Estimator(model_fn=lstm_model(TIMESTEPS, RNN_LAYERS, DENSE_LAYERS), model_dir=LOG_DIR)

# %%
# create a lstm instance and validation monitor
validation_monitor = learn.monitors.ValidationMonitor(X['val'], y['val'],every_n_steps=PRINT_STEPS,
                                                                                          early_stopping_rounds=1000)
regressor.fit(X['train'], y['train'], monitors=[validation_monitor], batch_size=BATCH_SIZE, steps=TRAINING_STEPS)
# Out:
# WARNING:tensorflow:Setting feature info to TensorSignature(dtype=tf.float32, shape=TensorShape([Dimension(None), Dimension(5), Dimension(16)]), is_sparse=False)
# WARNING:tensorflow:Setting targets info to TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(16)]), is_sparse=False)
# WARNING:tensorflow:dnn (from tensorflow.contrib.learn.python.learn.ops.dnn_ops) is deprecated and will be removed after 2016-08-01.
# Instructions for updating:
# Please use tf.contrib.layers.stack instead.
# WARNING:tensorflow:learn.ops.dnn is deprecated,     please use contrib.layers.dnn.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 5, 16), dtype=float32), required signatures: TensorSignature(dtype=tf.float32, shape=TensorShape([Dimension(None), Dimension(5), Dimension(16)]), is_sparse=False).
# ...

# %%
# predicted = regressor.predict(X['test'])

# # rmse = np.sqrt(((predicted - np.nan_to_num(y['test'])) ** 2).mean(axis=0))
# score = mean_squared_error(predicted, np.nan_to_num(y['test']))
# print ("MSE: %f" % score)

# %%
predicted = regressor.predict(X['test'])
corrected_predictions = np.zeros(predicted.shape)

for i, time in enumerate(predicted):
    for j, point in enumerate(time):
        if point <=1.05:
            corrected_predictions[i,j] = 1.0
        else:
            corrected_predictions[i,j] = point
# Out:
# WARNING:tensorflow:dnn (from tensorflow.contrib.learn.python.learn.ops.dnn_ops) is deprecated and will be removed after 2016-08-01.
# Instructions for updating:
# Please use tf.contrib.layers.stack instead.
# WARNING:tensorflow:learn.ops.dnn is deprecated,     please use contrib.layers.dnn.

# %%
new_rmse = np.sqrt(((corrected_predictions - np.nan_to_num(y['test'])) ** 2).mean(axis=0))
new_score = mean_squared_error(corrected_predictions, np.nan_to_num(y['test']))
print ("NEW MSE: %f" % new_score)
# Out:
# NEW MSE: 0.008449

# %% [markdown]
# # plotting graphs below here

# %%
#[0, 1, 2, 3, 14, 15, 16, 12, 13
plt.figure(figsize=(20,40))

plt.subplot(911)
plt.plot(corrected_predictions[:,0],label='5 min forecast')
plt.plot(np.nan_to_num(y['test'])[:,0],label='true 0')
plt.legend()

plt.subplot(912)
plt.plot(corrected_predictions[:,1],label='5 min forecast')
plt.plot(np.nan_to_num(y['test'])[:,1],label='true 1')
plt.legend()

plt.subplot(913)
plt.plot(corrected_predictions[:,2],label='5 min forecast')
plt.plot(np.nan_to_num(y['test'])[:,2],label='true 2')
plt.legend()

plt.subplot(914)
plt.plot(corrected_predictions[:,3],label='5 min forecast')
plt.plot(np.nan_to_num(y['test'])[:,3],label='true 3')
plt.legend()

plt.subplot(915)
plt.plot(corrected_predictions[:,4],label='5 min forecast')
plt.plot(np.nan_to_num(y['test'])[:,4],label='true 14')
plt.legend()

plt.subplot(916)
plt.plot(corrected_predictions[:,5],label='5 min forecast')
plt.plot(np.nan_to_num(y['test'])[:,5],label='true 15')
plt.legend()

plt.subplot(917)
plt.plot(corrected_predictions[:,6],label='5 min forecast')
plt.plot(np.nan_to_num(y['test'])[:,6],label='true 16')
plt.legend()

plt.subplot(918)
plt.plot(corrected_predictions[:,7],label='5 min forecast')
plt.plot(np.nan_to_num(y['test'])[:,7],label='true 12')
plt.legend()

plt.subplot(919)
plt.plot(corrected_predictions[:,8],label='5 min forecast')
plt.plot(np.nan_to_num(y['test'])[:,8],label='true 13')
plt.legend()

plt.show()

# %%
# , 24, 25, 26, 27, 28, 17, 29]
plt.figure(figsize=(20,30))

plt.subplot(711)
plt.plot(corrected_predictions[:,9],label='5 min forecast')
plt.plot(np.nan_to_num(y['test'])[:,9],label='true 24')
plt.legend()

plt.subplot(712)
plt.plot(corrected_predictions[:,10],label='5 min forecast')
plt.plot(np.nan_to_num(y['test'])[:,10],label='true 25')
plt.legend()

plt.subplot(713)
plt.plot(corrected_predictions[:,11],label='5 min forecast')
plt.plot(np.nan_to_num(y['test'])[:,11],label='true 26')
plt.legend()

plt.subplot(714)
plt.plot(corrected_predictions[:,12],label='5 min forecast')
plt.plot(np.nan_to_num(y['test'])[:,12],label='true 27')
plt.legend()

plt.subplot(715)
plt.plot(corrected_predictions[:,13],label='5 min forecast')
plt.plot(np.nan_to_num(y['test'])[:,13],label='true 28')
plt.legend()

plt.subplot(716)
plt.plot(corrected_predictions[:,14],label='5 min forecast')
plt.plot(np.nan_to_num(y['test'])[:,14],label='true 17')
plt.legend()

plt.subplot(717)
plt.plot(corrected_predictions[:,15],label='5 min forecast')
plt.plot(np.nan_to_num(y['test'])[:,15],label='true 29')
plt.legend()

plt.show()

# %% [markdown]
# # testing pickle stuff below here

# %%
# Save Model Using Pickle
import pandas
from sklearn import cross_validation
from sklearn.linear_model import LogisticRegression
import pickle

# %%
def my_model():
    url = "https://archive.ics.uci.edu/ml/machine-learning-databases/pima-indians-diabetes/pima-indians-diabetes.data"
    names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
    dataframe = pandas.read_csv(url, names=names)
    array = dataframe.values
    X = array[:,0:8]
    Y = array[:,8]
    test_size = 0.33
    seed = 7
    X_train, X_test, Y_train, Y_test = cross_validation.train_test_split(X, Y, test_size=test_size, random_state=seed)
    model = LogisticRegression()
    model.fit(X_train, Y_train)

# %%
model = my_model()

# %%
f = 'test.sav'
pickle.dump(model, open(f,'wb'))

# %%
loaded_model = pickle.load(open('test.sav', 'rb'))
result = loaded_model.score(X_test, Y_test)
print(result)

# %%
# url = "https://archive.ics.uci.edu/ml/machine-learning-databases/pima-indians-diabetes/pima-indians-diabetes.data"
# names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
# dataframe = pandas.read_csv(url, names=names)
# array = dataframe.values

# %%
# X = array[:,0:8]
# Y = array[:,8]
# test_size = 0.33
# seed = 7
# X_train, X_test, Y_train, Y_test = cross_validation.train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
# Fit the model on 33%
# model = LogisticRegression()
# model.fit(X_train, Y_train)

# %%
filename = 'finalized_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open('finalized_model.sav', 'rb'))
result = loaded_model.score(X_test, Y_test)
print(result)

# %%
import pickle

# %%
class this_is_stupid():
    def so_dumb(self):
        print "I can't believe this shit."
        
    def still_crazy(self,x,y):
        x = x
        y = y
        print x + y

# %%
model = this_is_stupid()

# %%
model.still_crazy(4,5)

# %%
filename = 'test.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open('test.sav', 'rb'))

# %%
data_string = pickle.dumps(model)

# %%
print data_string
